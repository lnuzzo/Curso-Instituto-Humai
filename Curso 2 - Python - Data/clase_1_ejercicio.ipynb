# %% [markdown]
# <a href="https://colab.research.google.com/github/institutohumai/cursos-python/blob/master/AnalisisDeDatos/1_Indexing/ejercicio/ejercicio.ipynb"> <img src='https://colab.research.google.com/assets/colab-badge.svg' /> </a>
# <div align="center"> Recordá abrir en una nueva pestaña </div>
#
#
# Para este ejercicio vamos a importar un conjunto de datos con el listado de colegios públicos de Bogotá del año 2016

# %%
import pandas as pd

# %%
df_colegios = pd.read_csv('https://www.datos.gov.co/api/views/qijw-htwa/rows.csv?accessType=DOWNLOAD')

# %%
df_colegios_local =pd.read_csv("../IHUMAI/datasets/LISTADO_COLEGIOS_BOGOTA.csv")
df_colegios_local.sample(2)
# Out:
#        año secretaria                              nombreestablecimiento  \
# 318   2016     BOGOTA  GIMN MODERNO JHON NEPER                       ...
# 1888  2016     BOGOTA                 COLEGIO JOSE MARIA CARBONELL (IED)
#
#         zona         direccion                       telefono  \
# 318   URBANA  KR 110 BIS 65 23                        4428226
# 1888  URBANA         KR 4 0 43  2333652 -- 2469683 -- 2469967
#
#               nombre_Rector   tipo_Establecimiento etnias  sector  ...  \
# 318   AURORA PILAR VILLAMIL       CENTRO EDUCATIVO    NaN     NaN  ...
# 1888    YOHAN MONTAÑO RAMOS  INSTITUCION EDUCATIVA    NaN     NaN  ...
#
#       numero_de_Sedes estado prestador_de_Servicio  propiedad_Planta_Fisica  \
# 318                 1    NaN       PERSONA NATURAL          PERSONA NATURAL
# 1888                1    NaN               OFICIAL                  OFICIAL
#
#       resguardo matricula_Contratada calendario internado  \
# 318   NO APLICA                   NO          A       NaN
# 1888  NO APLICA                   NO          A       NaN
#
#      estrato_Socio_Economico                    correo_Electronico
# 318                      NaN  gimnasiomodernojhonneper@hotmail.com
# 1888                     NaN       coldijosemariacarb4@redp.edu.co
#
# [2 rows x 30 columns]

# %% [markdown]
# ¿Cuáles son las columnas? ¿Cuántas filas tiene?

# %%
df_colegios.shape
# Out:
# (2404, 30)

# %%
df_colegios.sample(5)
# Out:
#        año  ...                                 correo_Electronico
# 1333  2016  ...                           liceodecroly@hotmail.com
# 1778  2016  ...  cedlaunionusme5@redp.edu.co -- crlaunion@gmail...
# 1386  2016  ...  ji_monachines@terra.com.co -- jimonachines@gma...
# 884   2016  ...  cedidguillermocano19@redp.edu.co  cedguillermo...
# 574   2016  ...  colegiorafaelg@007mundo.com                   ...
#
# [5 rows x 30 columns]

# %% [markdown]
# Seleccionen los colegios donde la propiedad de la planta física sea de una persona natural o comunidad religiosa.

# %%
df_col1 = df_colegios[(df_colegios['propiedad_Planta_Fisica']=='PERSONA NATURAL') | (df_colegios['propiedad_Planta_Fisica']=='COMUNIDAD RELIGIOSA')]
df_col1.sample(5)
# Out:
#        año  ...                                 correo_Electronico
# 2376  2016  ...                                                NaN
# 1813  2016  ...                                                NaN
# 2249  2016  ...                     liceocampestre2009@hotmail.com
# 1729  2016  ...  colnesacademica@hotmail.com nvaestancia@hotmai...
# 1133  2016  ...                              info@cgvermont.edu.co
#
# [5 rows x 30 columns]

# %% [markdown]
# ¿Hay alguno de estos colegios que sea para capacidades excepcionales?

# %%
df_col2 = df_colegios[df_colegios['capacidades_Excepcionales'].notnull()]
df_col2.sample(5)
# Out:
#        año  ...                                 correo_Electronico
# 1012  2016  ...  semillasverdes@hotmail.com                    ...
# 2231  2016  ...   g_tundama@hotmail.com -- claudia.tigre@gmail.com
# 1964  2016  ...  COLEGIOJONTHANSWIFT@YAHOO.COM.CO              ...
# 653   2016  ...  colegio.CEIC@colsubsidio.com -- colegioceicciu...
# 2282  2016  ...  info@colegiocalatrava.edu.co - rectoria@colegi...
#
# [5 rows x 30 columns]

# %% [markdown]
# ¿Cuáles son los colegios que ofrecen todos los niveles educativos? ¿Qué idiomas ofrecen?

# %%
df_col3 = df_colegios[df_colegios['idiomas'].notnull()]
df_col3['idiomas'].unique()
# Out:
# array(['INGLÉS', 'ALEMAN,FRANCES', 'HEBREO', 'FRANCES', 'INGLÉS,FRANCES',
#        'INGLÉS,ALEMAN,FRANCES', 'ITALIANO'], dtype=object)
